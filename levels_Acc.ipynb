# %% [markdown]
# This code is for showing the change of performance through the levels and to check the difficulty of the levels

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statistics as st

# %%
sample = pd.read_excel('Clouds-+18Competition.xlsx', usecols= "C,D,F,I,K,L,M,O")
#print(sample)

rows = len(sample)

# %%
def LevelCheck (level, T, F):
    if level == 2:
        if (T+F) == 2:
            return 1
        else:
            return False
    elif level == 4:
        if (T+F) == 3:
            return 2
        else:
            return False
    elif level == 7:
        if (T+F) == 4:
            return 3
        else:
            return False
    elif level == 8:
        if (T+F) == 4:
            return 4
        else:
            return False
    elif level == 11:
        if (T+F) == 5:
            return 5
        else:
            return False

# %%
def levels_accuracy(sample):
    LevelsAccSum = np.zeros(5)  #the sum of accuracy for each level
    LevelNum = np.zeros(5)      #for counting each level's num

    for i in range(rows):
        level = int(sample.iloc[i ,1])
        T = int(sample.iloc[i, 4])
        F = int(sample.iloc[i, 5])
        
        LIndex = LevelCheck(level, T, F)        #if the level is completed, it gets the index of the level [2,4,7,8,11]
        if LIndex:
            Acc = T / (T+F)
            LevelNum[(LIndex-1)] += 1  
            LevelsAccSum[(LIndex-1)] += Acc
        
    LevelsAcc = [LevelsAccSum[i]/LevelNum[i] for i in range(5) ]
    return LevelsAcc
    #print(LevelsAcc)

# %%
levelsAcc = levels_accuracy(sample)
levels = [2, 4, 7, 8, 11]
plt.plot(levels, levelsAcc)
plt.show()
